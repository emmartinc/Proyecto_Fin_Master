# %% [markdown]
# # MODULO_04 AJUSTE EMBEDDINGS CON TERMINOS TECNICOS

# %% [markdown]
# # ---------------------------------------------
# # ATENCIÓN - FIJAR ESTAS VARIABLES ANTES DE EJECUTAR
# # ---------------------------------------------

# %%
nombre_lote = "LOTE_20250614"

nombre_modulo = "MODULO_04"

# %%
# ---------------------------------------------
# Configuración del entorno (Colab y Local)
# ---------------------------------------------

try:
    import google.colab
    EN_COLAB = True
except ImportError:
    EN_COLAB = False

if EN_COLAB:
    from google.colab import drive
    drive.mount("/content/drive", force_remount=True)
    ruta_base = "/content/drive/MyDrive/TFM_EVA_MARTIN/Modulos"
else:
    ruta_base = "G:/Mi unidad/TFM_EVA_MARTIN/Modulos"

print(f"Entorno detectado: {'Google Colab' if EN_COLAB else 'Local'}")
print(f"Ruta base: {ruta_base}")

lote_id = nombre_lote.replace("LOTE_", "")
# Out:
# Mounted at /content/drive
# Entorno detectado: Google Colab
# Ruta base: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos

# %%
import sys
import os
ruta_config = os.path.join(ruta_base, "config.yaml")

if ruta_base not in sys.path:
    sys.path.append(ruta_base)
import yaml

# Cargar configuración desde el archivo YAML
with open(ruta_config, "r", encoding="utf-8") as f:
    config = yaml.safe_load(f)

config = yaml.safe_load(open(ruta_config))

# Extraer bloque de parámetros (KeyError si falta alguna clave)
params = config["parametros"]

# %% [markdown]
# # Carga utilidades comunes e inicialización del entorno

# %%
import pandas as pd

import utilidades_comunes

# 1. Configurar logger
import logging
logger = utilidades_comunes.configurar_logger(nombre_modulo, ruta_logs=os.path.join(ruta_base, nombre_modulo, "logs"))
logger.setLevel(logging.DEBUG)

# 2. Inicializar entorno
entorno = utilidades_comunes.inicializar_entorno(nombre_modulo, nombre_lote, ruta_base, ruta_config, logger=logger)
# Out:
# 2025-06-28 13:50:56,323 - INFO - 📁 Entorno inicializado para MODULO_04
# INFO:MODULO_04:📁 Entorno inicializado para MODULO_04
# 2025-06-28 13:50:56,325 - INFO - 📂 Ruta entrada: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_03/./salida
# INFO:MODULO_04:📂 Ruta entrada: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_03/./salida
# 2025-06-28 13:50:56,327 - INFO - 📂 Ruta salida: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_04/./salida
# INFO:MODULO_04:📂 Ruta salida: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_04/./salida
# 2025-06-28 13:50:56,328 - INFO - 📂 Ruta logs: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_04/./logs
# INFO:MODULO_04:📂 Ruta logs: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_04/./logs
# 2025-06-28 13:50:56,329 - INFO - 📂 Ruta ejemplos: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_04/./ejemplos
# INFO:MODULO_04:📂 Ruta ejemplos: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_04/./ejemplos
# 2025-06-28 13:50:56,330 - INFO - 🔗 Módulo anterior: MODULO_03
# INFO:MODULO_04:🔗 Módulo anterior: MODULO_03
# 2025-06-28 13:50:56,331 - INFO - 🆔 Lote ID: 20250614
# INFO:MODULO_04:🆔 Lote ID: 20250614

# %%
# ---------------------------------------------
# 2. Cargar términos técnicos desde JSON
# ---------------------------------------------
import json
ruta_json = os.path.join(entorno["ruta_entrada"], "terminos_tecnicos.json")
with open(ruta_json, "r", encoding="utf-8") as f:
    terminos_tecnicos = json.load(f)

logger.info(f"📄 Términos técnicos cargados: {len(terminos_tecnicos)}")
# Out:
# 2025-06-28 13:51:00,607 - INFO - 📄 Términos técnicos cargados: 14
# INFO:MODULO_04:📄 Términos técnicos cargados: 14

# %% [markdown]
# # Carga y analisis dataset de entrada

# %%
patron_busqueda = os.path.join(
    entorno["ruta_entrada"],
    f"dataset_{entorno['nombre_modulo_anterior'].lower()}_{entorno['lote_id']}*.csv"
)

import glob
archivos_encontrados = glob.glob(patron_busqueda)

if not archivos_encontrados:
    raise FileNotFoundError(f"No se encontró archivo de entrada para el lote {nombre_lote} con patrón: {patron_busqueda}")

fichero_entrada = archivos_encontrados[0]
df_entrada = utilidades_comunes.cargar_dataset(fichero_entrada, logger=logger)

utilidades_comunes.mostrar_muestra_dataset(df_entrada, "dataset de entrada", logger=logger)
utilidades_comunes.guardar_muestra_dataset(df_entrada, "entrada", entorno["ruta_ejemplos"], logger=logger, n=1)


df = df_entrada.copy()
# Out:
# 2025-06-28 13:51:29,343 - INFO - ✅ Dataset cargado desde /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_03/./salida/dataset_modulo_03_20250614.csv (140 filas, 4 columnas)
# INFO:MODULO_04:✅ Dataset cargado desde /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_03/./salida/dataset_modulo_03_20250614.csv (140 filas, 4 columnas)
# 2025-06-28 13:51:29,344 - INFO - --- Muestra de dataset de entrada (primeras 5 filas) ---
# INFO:MODULO_04:--- Muestra de dataset de entrada (primeras 5 filas) ---
# 2025-06-28 13:51:29,346 - INFO - Filas totales: 140, Columnas totales: 4
# INFO:MODULO_04:Filas totales: 140, Columnas totales: 4
# 2025-06-28 13:51:29,369 - INFO -
# | nomfichero                                                                                            | etiqueta   | transcripcion                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# |:------------------------------------------------------------------------------------------------------|:-----------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# | Negativo_SD23-03822_[965021512]_MERIDIANO_900_GEN._2023-03-03_23-08-14_620135618_procesado_limpio.txt | Negativo   | Agente: Buenas noches, doña CLIENTE. Mi nombre es AGENTE, le llamo del Departamento de Asistencia de Seguros Meridiano. Doña CLIENTE, en primer lugar, trasladarle tanto a usted como al resto de familiares nuestras más sinceras condolencias por el fallecimiento de doña DIFUNTO, de su madre. Cliente: De nada, doña CLIENTE. Agente: Doña CLIENTE, le llamo porque nos ha informado Isabel, la cobradora, nos ha indicado que su madre se encuentra en el hospital de Ronda, ¿es correcto? Cliente: Sí, es correcto. Agente: Y desean ustedes realizar el velatorio en Olvera, ¿es así? Cliente: Sí, sí. Agente: En calle Azuaga 14, en el terratorio, no. A ver, un momentito, en calle Azuaga me dijo. Cliente: Calle Azuaga 14. Agente: Calle Azuaga 14, vale. Posteriormente, ¿lo que desearían dejó doña DIFUNTO indicado si lo que ella quería era entierro o incineración? Cliente: No, entierro, entierro. Agente: Entierro, vale. ¿Tienen ustedes dicho en propiedad, doña CLIENTE? Cliente: Sí, sí, tiene, tiene. Agente: Dicho en propiedad, vale. Pues un momentito que lo note aquí. Cliente: Doña CLIENTE, el dicho que tienen ustedes en propiedad, ¿saben si está ocupado o está vacío? Agente: Está ocupado con resto, pero vamos, están los restos en saco y todo. O sea, que ya hace muchos años, ¿verdad? Cliente: Sí, muchísimos. Agente: Vale. Muchísimos, son de los padres. Ah, vale. Ella ha muerto con 94 años. Vale. Agente: Pues, doña DIFUNTO, o perdón, doña CLIENTE, le comento, voy a dar ya mismo parte a los servicios funerarios para que ellos vayan a atenderla al hospital. Cliente: Vale. Agente: ¿Le van a llamar ellos para indicarle cuánto tiempo aproximadamente van a tardar en llegar? Cliente: Vale. Agente: Nosotros, doña CLIENTE, quedamos a su disposición en un teléfono gratuito que va a recibir a través de un mensaje y estamos las 24 horas, por si nos necesita para algo. Cliente: Vale. Agente: Doña CLIENTE, bueno, entiendo que el fallecimiento de doña DIFUNTO no guarda ninguna relación con el COVID-19, ¿es así? Cliente: No, no, no, nada. Agente: Vale. Otras cosas, otras cuestiones. Vale. Agente: Pues cualquier cosita, como le indicaba, quedamos a su disposición y nuevamente nuestras condolencias por la pérdida. Cliente: Vale. Agente: Entonces, ¿a ellos nos llaman y no avisan? Cliente: Sí, yo ahora voy a llamarles, les voy a dar todos los datos y lo que ustedes desean hacer y su número de teléfono para que ellos le llamen. Agente: ¿De acuerdo? Cliente: Vale, vale. Agente: Muchas gracias. A usted, y de verdad que lamentamos la pérdida. Cliente: Gracias. Agente: Un saludo. Cliente: Gracias. Agente: Gracias. Cliente: Muchas gracias.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# | Positivo_[965641606]_MERIDIANO_902_2023-02-27_13-15-09_procesado_limpio.txt                           | Positivo   | Agente: Sí. Hola, buenas. Hablo con XXXXXX. ¿De cuál es el quién? Mi nombre es XXXXXX. Le llamo del Departamento de Asistencia de Seguros Meridiano. Sí. Dígame. Es usted Don XXXXXX, entiendo. Sí. En primer lugar, permítame trasladarle mis más sinceras condolencias por la pérdida de doña XXXXXX. Gracias. Nada, el motivo de mi llamada era porque queríamos corroborar con ustedes los datos. Ha fallecido su suegro en domicilio, ¿verdad? En la calle XXXXXXXX, en Lora de Estepa. Vale. Queríamos confirmar con usted. ¿Van a desear velar en Lora de Estepa? Sí. ¿En Canatorio? En Canatorio, sí. En Canatorio, en Lora de Estepa. Vale. ¿Sabían ustedes si los deseos de Don XXXXXX era ser enterrado o incinerado? No. Vale. De acuerdo. Pues le indico que vamos a dar parte ahora los compañeros prestadores del servicio para que se dirijan al domicilio lo antes posible. Le van a llamar antes para indicarle el tiempo que van a tardar. Sí, bueno, yo quería comentarles, era mejor comentárselo a ellos, que si una vez que lo arreglaran y demás, el traslado lo hiciesen un poquito más tarde, porque estamos esperando los cuñados, que están de viaje, y creo yo que llegarían solo a las cuatro de la tarde o por ahí, para luego llevarlo hasta Canatorio, está a cinco kilómetros. De acuerdo. No se preocupe. Ahora, cuando los compañeros le llamen, se lo indica y ellos se impongan. De acuerdo. Llevamos a su disposición Don XXXXXX Lamento de la pérdida. Gracias. Adiós. Un saludo. Igualmente. Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Client ...
# | Positivo_[965641606]_MERIDIANO_902_2023-02-28_11-05-56_procesado_limpio.txt                           | Positivo   | Agente: ¿Sí? Hola, buenos días. ¿Hablo con don XXXXXX? Sí, soy yo. Mi nombre es XXXXXX y llamo al Departamento de Asistencia de Aseguros de Liriano. Sí. En lugar, permítame trasladarle mis más sinceras condolencias por la prueba de su padre, don José. Gracias. De nada. El motivo de mi llamada era para saber si todo el servicio se había estado desarrollando correctamente y conformar a la atención de su familia. Cliente: Sí, sí, perfecto, todo perfecto. Agente: De acuerdo. También quería indicarle que íbamos a proceder a activar el servicio de gestoría. Es un servicio gratuito. Le llamarían en unos 10 a 15 días el abogado para ayudarles con todos los trámites que tengan ahora con la Administración Pública. Cliente: De acuerdo. Agente: Conocen ustedes el horario de misa, ¿verdad? Cliente: ¿Cómo? Agente: Perdón. Conocen ustedes la misa latina en un par de horitas. Cliente: Sí, sí, sí. Agente: De acuerdo. Pues muchas gracias por atenderme la llamada, don XXXXXX. Cliente: De nada. Agente: Que hagamos la exposición. Cliente: De nada. Agente: Muchas gracias. A usted. Salud. Cliente: Salud.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# | Positivo_[965641606]_MERIDIANO_902_2023-02-28_09-12-59_617980_procesado_limpio.txt                    | Positivo   | Agente: Bienvenido a Meridiano. Recuerde que puede llamar a nuestro número gratuito 900-408-200. Por su seguridad, esta llamada podrá ser grabada. Usted consiente en que los datos que facilite se incorporen en un fichero titularidad de Meridiano S. A., con la finalidad de gestionar la prestación del servicio. Si ya conoce nuestra política de protección de datos y no desea escucharla nuevamente, pulse o diga cero. Cero. La rogamos consulte la política de privacidad en www. segurosmeridiano. com Política de privacidad. Madre mía. Si su llamada es para comunicar un fallecimiento, pulse o diga 1. Si desea comunicar un siniestro de hogar, pulse o diga 2. Para cualquiera de la opción, espere. 1. ¿Sí? Agente: Hola, buenos días. ¿En qué puedo ayudarle? Agente: Buenos días. Mire, que llamaba para comunicar un fallecimiento. Y he estado llamando a la gente, no coge el teléfono. Vale. ¿Es usted familiar de la persona fallecida? Agente: Su marido. Su marido. Vale. ¿Y podría decir cuál es el nombre de usted para dirigirme? Agente: XXXXXX. Vale, don XXXXXX. Agente: Pues en primer lugar le transmito mis condolencias por el fallecimiento. ¿Dónde vamos? ¿Le puede dar un momentillo a mi DNI? Agente: Sí. Vale. Agente: Disculpe, ¿necesitaríamos el DNI de la persona fallecida para buscar la póliza? Agente: Muy bien. Agente: ¿Y el nombre y los apellidos son? Agente: XXXXXX. Agente: Vale. Agente: Pues un momentito por favor que revisemos los datos de la póliza. Agente: Vale. Agente: Disculpe, don XXXXXX. ¿Dónde ha fallecido doña XXXXXX? Agente: En el hospital La Merced de Ozuna. Agente: Vale. Agente: Por protocolo sanitario, ¿debemos preguntarle si el fallecimiento hubiera podido tener relación con COVID? Agente: No, no ha tenido relación con COVID, no. Agente: Vale. Agente: Disculpe, ¿nosotros tenemos configurada la póliza para hacer el brelatorio en Gilena? Agente: ¿Sería así como querría hacerlo la familia? Agente: Sí, sí, sí, sí. Agente: Correcto. Agente: Vale. Agente: Y no sé si conocían los deseos de doña XXXXXX, si deseaba ser enterrada o incinerada. Agente: No, enterrada, enterrada. Agente: Enterrada allí también, ¿verdad? Agente: Sí, allí también, en el interior de allí. Agente: Vale. Agente: No sé si tienen algún nicho ustedes familiar o sería el de la póliza que tienen contratado. Agente: Sí, tenemos que. Agente: Sí, no sé si disponen de algún nicho familiar o sería el que tienen contratado en la póliza. Agente: No, es que tenemos contratado a la póliza. Agente: Vale. Agente: Pues dígame, por favor, don XXXXXX, ¿cuál sería su número de teléfono de contacto para que le llamen los compañeros? Agente: XXX-XXX-XXX. Agente: Vale. Agente: Pues don XXXXXX, nos podemos ir a avisar. ¿A dónde voy? ¿Sí? ¿Sí, me dice? Agente: Sí, le comentaba que vamos a ir dando los datos a los compañeros para que le llamen ahora en 15 minutos aproximadamente y les informarán de lo que tardan en acudir al hospital a atenderles, ¿de acuerdo? Agente: Muy bien, gracias. Agente: Y también recibirá un mensaje de meridiano con nuestro número de teléfono por si tienen alguna duda o consulta. Agente: Muy bien, gracias. Agente: Gracias. Agente: Gracias, buenos días. Agente: Gracias. Cliente: Muy bien, gracias. Gracias. Y también recibirá un mensaje de meridiano con nuestro número de teléfono por si tienen alguna duda o consulta. Muy bien, gracias. Gracias, buenos días. Gracias.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# | Positivo_[965641606]_MERIDIANO_902_2023-02-28_10-43-08_procesado_limpio.txt                           | Positivo   | Agente: ¿Dígame? Hola, ¿hablo con doña XXXXXX? Sí, dígame. Mi nombre es Angela, le llamo del Departamento de Asistencia de Seguros Meridiano. Sí. En primer lugar, permítame trasladarle mis más sinceras condolencias por la pérdida de don XXXXXX. Muchas gracias. De nada. El motivo de mi llamada era para saber que el servicio se está desarrollando todo correctamente y conforme a los deseos de la familia. Sí, sí, sí, todo correcto. De acuerdo. Conocen ustedes el horario de misa, ¿verdad? Sí, a las seis de la tarde. De acuerdo. Doña XXXXXX, también quería indicarle que vamos a proceder a activarles el servicio de gestoría para que les llame el abogado de unos 10 a 15 días. Es un servicio gratuito incluido en la póliza para ayudarles con todos los trámites que tengan ahora con la administración pública. Muy bien, muy bien. Muchas gracias. De acuerdo. Cualquier duda que tengan ustedes, cualquier consulta, estamos las 24 horas a su disposición. De acuerdo. Muchas gracias por atenderme la llamada. De nada. Gracias. Hasta luego. Cliente: (no hay texto) ¿Listo para etiquetar? ¡Vamos!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# INFO:MODULO_04:
# | nomfichero                                                                                            | etiqueta   | transcripcion                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# |:------------------------------------------------------------------------------------------------------|:-----------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# | Negativo_SD23-03822_[965021512]_MERIDIANO_900_GEN._2023-03-03_23-08-14_620135618_procesado_limpio.txt | Negativo   | Agente: Buenas noches, doña CLIENTE. Mi nombre es AGENTE, le llamo del Departamento de Asistencia de Seguros Meridiano. Doña CLIENTE, en primer lugar, trasladarle tanto a usted como al resto de familiares nuestras más sinceras condolencias por el fallecimiento de doña DIFUNTO, de su madre. Cliente: De nada, doña CLIENTE. Agente: Doña CLIENTE, le llamo porque nos ha informado Isabel, la cobradora, nos ha indicado que su madre se encuentra en el hospital de Ronda, ¿es correcto? Cliente: Sí, es correcto. Agente: Y desean ustedes realizar el velatorio en Olvera, ¿es así? Cliente: Sí, sí. Agente: En calle Azuaga 14, en el terratorio, no. A ver, un momentito, en calle Azuaga me dijo. Cliente: Calle Azuaga 14. Agente: Calle Azuaga 14, vale. Posteriormente, ¿lo que desearían dejó doña DIFUNTO indicado si lo que ella quería era entierro o incineración? Cliente: No, entierro, entierro. Agente: Entierro, vale. ¿Tienen ustedes dicho en propiedad, doña CLIENTE? Cliente: Sí, sí, tiene, tiene. Agente: Dicho en propiedad, vale. Pues un momentito que lo note aquí. Cliente: Doña CLIENTE, el dicho que tienen ustedes en propiedad, ¿saben si está ocupado o está vacío? Agente: Está ocupado con resto, pero vamos, están los restos en saco y todo. O sea, que ya hace muchos años, ¿verdad? Cliente: Sí, muchísimos. Agente: Vale. Muchísimos, son de los padres. Ah, vale. Ella ha muerto con 94 años. Vale. Agente: Pues, doña DIFUNTO, o perdón, doña CLIENTE, le comento, voy a dar ya mismo parte a los servicios funerarios para que ellos vayan a atenderla al hospital. Cliente: Vale. Agente: ¿Le van a llamar ellos para indicarle cuánto tiempo aproximadamente van a tardar en llegar? Cliente: Vale. Agente: Nosotros, doña CLIENTE, quedamos a su disposición en un teléfono gratuito que va a recibir a través de un mensaje y estamos las 24 horas, por si nos necesita para algo. Cliente: Vale. Agente: Doña CLIENTE, bueno, entiendo que el fallecimiento de doña DIFUNTO no guarda ninguna relación con el COVID-19, ¿es así? Cliente: No, no, no, nada. Agente: Vale. Otras cosas, otras cuestiones. Vale. Agente: Pues cualquier cosita, como le indicaba, quedamos a su disposición y nuevamente nuestras condolencias por la pérdida. Cliente: Vale. Agente: Entonces, ¿a ellos nos llaman y no avisan? Cliente: Sí, yo ahora voy a llamarles, les voy a dar todos los datos y lo que ustedes desean hacer y su número de teléfono para que ellos le llamen. Agente: ¿De acuerdo? Cliente: Vale, vale. Agente: Muchas gracias. A usted, y de verdad que lamentamos la pérdida. Cliente: Gracias. Agente: Un saludo. Cliente: Gracias. Agente: Gracias. Cliente: Muchas gracias.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# | Positivo_[965641606]_MERIDIANO_902_2023-02-27_13-15-09_procesado_limpio.txt                           | Positivo   | Agente: Sí. Hola, buenas. Hablo con XXXXXX. ¿De cuál es el quién? Mi nombre es XXXXXX. Le llamo del Departamento de Asistencia de Seguros Meridiano. Sí. Dígame. Es usted Don XXXXXX, entiendo. Sí. En primer lugar, permítame trasladarle mis más sinceras condolencias por la pérdida de doña XXXXXX. Gracias. Nada, el motivo de mi llamada era porque queríamos corroborar con ustedes los datos. Ha fallecido su suegro en domicilio, ¿verdad? En la calle XXXXXXXX, en Lora de Estepa. Vale. Queríamos confirmar con usted. ¿Van a desear velar en Lora de Estepa? Sí. ¿En Canatorio? En Canatorio, sí. En Canatorio, en Lora de Estepa. Vale. ¿Sabían ustedes si los deseos de Don XXXXXX era ser enterrado o incinerado? No. Vale. De acuerdo. Pues le indico que vamos a dar parte ahora los compañeros prestadores del servicio para que se dirijan al domicilio lo antes posible. Le van a llamar antes para indicarle el tiempo que van a tardar. Sí, bueno, yo quería comentarles, era mejor comentárselo a ellos, que si una vez que lo arreglaran y demás, el traslado lo hiciesen un poquito más tarde, porque estamos esperando los cuñados, que están de viaje, y creo yo que llegarían solo a las cuatro de la tarde o por ahí, para luego llevarlo hasta Canatorio, está a cinco kilómetros. De acuerdo. No se preocupe. Ahora, cuando los compañeros le llamen, se lo indica y ellos se impongan. De acuerdo. Llevamos a su disposición Don XXXXXX Lamento de la pérdida. Gracias. Adiós. Un saludo. Igualmente. Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Cliente: Agente: Client ...
# ...
# |:-----------------|--------:|---------:|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------:|
# | nomfichero       |     140 |      140 | Negativo_SD23-03822_[965021512]_MERIDIANO_900_GEN._2023-03-03_23-08-14_620135618_procesado_limpio.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |      1 |
# | etiqueta         |     140 |        3 | Positivo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |     95 |
# | transcripcion    |     140 |      133 | Agente: Buenas noches, doña CLIENTE. Mi nombre es AGENTE, le llamo del Departamento de Asistencia de Seguros Meridiano. Doña CLIENTE, en primer lugar, trasladarle tanto a usted como al resto de familiares nuestras más sinceras condolencias por el fallecimiento de doña DIFUNTO, de su madre. Cliente: De nada, doña CLIENTE. Agente: Doña CLIENTE, le llamo porque nos ha informado Isabel, la cobradora, nos ha indicado que su madre se encuentra en el hospital de Ronda, ¿es correcto? Cliente: Sí, es correcto. Agente: Y desean ustedes realizar el velatorio en Olvera, ¿es así? Cliente: Sí, sí. Agente: En calle Azuaga 14, en el terratorio, no. A ver, un momentito, en calle Azuaga me dijo. Cliente: Calle Azuaga 14. Agente: Calle Azuaga 14, vale. Posteriormente, ¿lo que desearían dejó doña DIFUNTO indicado si lo que ella quería era entierro o incineración? Cliente: No, entierro, entierro. Agente: Entierro, vale. ¿Tienen ustedes dicho en propiedad, doña CLIENTE? Cliente: Sí, sí, tiene, tiene. Agente: Dicho en propiedad, vale. Pues un momentito que lo note aquí. Cliente: Doña CLIENTE, el dicho que tienen ustedes en propiedad, ¿saben si está ocupado o está vacío? Agente: Está ocupado con resto, pero vamos, están los restos en saco y todo. O sea, que ya hace muchos años, ¿verdad? Cliente: Sí, muchísimos. Agente: Vale. Muchísimos, son de los padres. Ah, vale. Ella ha muerto con 94 años. Vale. Agente: Pues, doña DIFUNTO, o perdón, doña CLIENTE, le comento, voy a dar ya mismo parte a los servicios funerarios para que ellos vayan a atenderla al hospital. Cliente: Vale. Agente: ¿Le van a llamar ellos para indicarle cuánto tiempo aproximadamente van a tardar en llegar? Cliente: Vale. Agente: Nosotros, doña CLIENTE, quedamos a su disposición en un teléfono gratuito que va a recibir a través de un mensaje y estamos las 24 horas, por si nos necesita para algo. Cliente: Vale. Agente: Doña CLIENTE, bueno, entiendo que el fallecimiento de doña DIFUNTO no guarda ninguna relación con el COVID-19, ¿es así? Cliente: No, no, no, nada. Agente: Vale. Otras cosas, otras cuestiones. Vale. Agente: Pues cualquier cosita, como le indicaba, quedamos a su disposición y nuevamente nuestras condolencias por la pérdida. Cliente: Vale. Agente: Entonces, ¿a ellos nos llaman y no avisan? Cliente: Sí, yo ahora voy a llamarles, les voy a dar todos los datos y lo que ustedes desean hacer y su número de teléfono para que ellos le llamen. Agente: ¿De acuerdo? Cliente: Vale, vale. Agente: Muchas gracias. A usted, y de verdad que lamentamos la pérdida. Cliente: Gracias. Agente: Un saludo. Cliente: Gracias. Agente: Gracias. Cliente: Muchas gracias. |      3 |
# | texto_etiquetado |     140 |      133 | Agente: Buenas noches, doña CLIENTE. Mi nombre es AGENTE, le llamo del Departamento de Asistencia de Seguros Meridiano. Doña CLIENTE, en primer lugar, trasladarle tanto a usted como al resto de familiares nuestras más sinceras condolencias por el fallecimiento de doña DIFUNTO, de su madre. Cliente: De nada, doña CLIENTE. Agente: Doña CLIENTE, le llamo porque nos ha informado Isabel, la cobradora, nos ha indicado que su madre se encuentra en el hospital de Ronda, ¿es correcto? Cliente: Sí, es correcto. Agente: Y desean ustedes realizar el velatorio en Olvera, ¿es así? Cliente: Sí, sí. Agente: En calle Azuaga 14, en el terratorio, no. A ver, un momentito, en calle Azuaga me dijo. Cliente: Calle Azuaga 14. Agente: Calle Azuaga 14, vale. Posteriormente, ¿lo que desearían dejó doña DIFUNTO indicado si lo que ella quería era entierro o incineración? Cliente: No, entierro, entierro. Agente: Entierro, vale. ¿Tienen ustedes dicho en propiedad, doña CLIENTE? Cliente: Sí, sí, tiene, tiene. Agente: Dicho en propiedad, vale. Pues un momentito que lo note aquí. Cliente: Doña CLIENTE, el dicho que tienen ustedes en propiedad, ¿saben si está ocupado o está vacío? Agente: Está ocupado con resto, pero vamos, están los restos en saco y todo. O sea, que ya hace muchos años, ¿verdad? Cliente: Sí, muchísimos. Agente: Vale. Muchísimos, son de los padres. Ah, vale. Ella ha muerto con 94 años. Vale. Agente: Pues, doña DIFUNTO, o perdón, doña CLIENTE, le comento, voy a dar ya mismo parte a los servicios funerarios para que ellos vayan a atenderla al hospital. Cliente: Vale. Agente: ¿Le van a llamar ellos para indicarle cuánto tiempo aproximadamente van a tardar en llegar? Cliente: Vale. Agente: Nosotros, doña CLIENTE, quedamos a su disposición en un teléfono gratuito que va a recibir a través de un mensaje y estamos las 24 horas, por si nos necesita para algo. Cliente: Vale. Agente: Doña CLIENTE, bueno, entiendo que el fallecimiento de doña DIFUNTO no guarda ninguna relación con el COVID-19, ¿es así? Cliente: No, no, no, nada. Agente: Vale. Otras cosas, otras cuestiones. Vale. Agente: Pues cualquier cosita, como le indicaba, quedamos a su disposición y nuevamente nuestras condolencias por la pérdida. Cliente: Vale. Agente: Entonces, ¿a ellos nos llaman y no avisan? Cliente: Sí, yo ahora voy a llamarles, les voy a dar todos los datos y lo que ustedes desean hacer y su número de teléfono para que ellos le llamen. Agente: ¿De acuerdo? Cliente: Vale, vale. Agente: Muchas gracias. A usted, y de verdad que lamentamos la pérdida. Cliente: Gracias. Agente: Un saludo. Cliente: Gracias. Agente: Gracias. Cliente: Muchas gracias. |      3 |
# 2025-06-28 13:51:29,386 - INFO - ------------------------------------------------------------
# INFO:MODULO_04:------------------------------------------------------------
# 2025-06-28 13:51:29,393 - INFO - 💾 Muestra guardada en /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_04/./ejemplos/muestra_entrada.csv (1 filas)
# INFO:MODULO_04:💾 Muestra guardada en /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_04/./ejemplos/muestra_entrada.csv (1 filas)

# %%
# ---------------------------------------------
# 3. Preparación de textos para ajuste de embeddings (sin división si es pequeño)
# ---------------------------------------------
from collections import Counter

# Limpieza y mapeo de etiquetas
etiquetas_map = {"Positivo": 0, "Neutro": 1, "Negativo": 2}
df = df.dropna(subset=["texto_etiquetado"])
df["texto_etiquetado"] = df["texto_etiquetado"].astype(str).str.strip()
df["label"] = df["etiqueta"].map(etiquetas_map)

# Comprobamos si se puede dividir de forma segura
conteo = Counter(df["label"])
minimo_por_clase = min(conteo.values())

if minimo_por_clase < 3 or len(df) < 30:
    logger.warning("⚠️ Dataset demasiado pequeño para dividir. Usando todo como train_texts.")
    train_texts = df["texto_etiquetado"].tolist()
else:
    from sklearn.model_selection import train_test_split

    df_train, df_temp = train_test_split(df, test_size=0.2, random_state=42, stratify=df["label"])
    df_val, df_test = train_test_split(df_temp, test_size=0.5, random_state=42, stratify=df_temp["label"])

    train_texts = df_train["texto_etiquetado"].tolist()
    val_texts   = df_val["texto_etiquetado"].tolist()
    test_texts  = df_test["texto_etiquetado"].tolist()

    train_labels = df_train["label"].tolist()
    val_labels   = df_val["label"].tolist()
    test_labels  = df_test["label"].tolist()

    # Guardar subconjuntos
    df_train.to_csv(os.path.join(entorno["ruta_salida"], "train.csv"), index=False)
    df_val.to_csv(os.path.join(entorno["ruta_salida"], "val.csv"), index=False)
    df_test.to_csv(os.path.join(entorno["ruta_salida"], "test.csv"), index=False)

    logger.info(f"🗂 Dataset dividido: {len(train_texts)} train, {len(val_texts)} val, {len(test_texts)} test")

# Mostrar conteo de clases
print("\n📊 Número de muestras por clase:")
print(df["etiqueta"].value_counts())

# Mostrar algunos ejemplos de transcripciones
print("\n📝 Ejemplo de transcripciones:")
for i, fila in df.sample(n=min(2, len(df))).iterrows():  # muestra 2 ejemplos como máximo
    print(f"\n📁 {fila['nomfichero']}  [{fila['etiqueta']}]")
    print(f"{fila['texto_etiquetado'][:300]}...")
# Verificar que las conversiones se hicieron correctamente
print(df_train["label"].unique())
print(df_train["label"].dtype)
# Out:
# 2025-06-28 13:54:15,815 - INFO - 🗂 Dataset dividido: 112 train, 14 val, 14 test
# INFO:MODULO_04:🗂 Dataset dividido: 112 train, 14 val, 14 test
# 📊 Número de muestras por clase:
# etiqueta
# Positivo    95
# Neutro      25
# Negativo    20
# Name: count, dtype: int64
#
# 📝 Ejemplo de transcripciones:
#
# 📁 Positivo_SD23-03590_[965021512]_MERIDIANO_900_GEN._2023-03-01_12-55-57_679839976_procesado_limpio.txt  [Positivo]
# Agente: Sí, dígame. Agente: Hola, buenos días. ¿Doña CLIENTE? Agente: Sí, soy yo. Dígame. Agente: Mire, mi nombre es AGENTE, le llamo del Departamento de Asistencia de Seguros Meridiano. Doña CLIENTE, primero de todo transmitirle mis más sinceras condolencias por el fallecimiento de su tía, doña DIF...
#
# 📁 Positivo_SD23-03630_[965021512]_MERIDIANO_900_GEN._2023-03-10_11-59-17_647288618_procesado_limpio.txt  [Positivo]
# Agente: Bienvenido a Meridiano. Por su seguridad, esta llamada podrá ser grabada. Usted consiente en que los datos que facilite se incorporen en un fichero titularidad de Meridiano S. A. con la finalidad de gestionar la prestación del servicio. Si ya conoce nuestra política de protección de datos y ...
# [2 0 1]
# int64

# %% [markdown]
# # PASO 4: Procesamiento específico del módulo

# %%
# ---------------------------------------------
# Funcion para detectar términos nuevos - porque los terminos técnicos
# son acumulativos
# ---------------------------------------------
def detectar_terminos_nuevos(terminos_tecnicos, ruta_tokenizer_anterior, logger=None):
    """
    Compara el vocabulario actual con los términos técnicos nuevos
    y devuelve únicamente los que aún no existen.

    Args:
        terminos_tecnicos (list): Lista de términos del JSON.
        ruta_tokenizer_anterior (str): Carpeta con tokenizer previo.
        logger (logging.Logger, optional): Para registrar mensajes.

    Returns:
        list: Lista de términos nuevos que deben añadirse.
    """
    from transformers import LongformerTokenizerFast

    if os.path.exists(ruta_tokenizer_anterior):
        tokenizer_tmp = LongformerTokenizerFast.from_pretrained(ruta_tokenizer_anterior)
        tokens_existentes = set(tokenizer_tmp.get_vocab().keys())
        if logger:
            logger.info("📥 Tokenizador anterior cargado para comparación de vocabulario.")
    else:
        tokenizer_tmp = LongformerTokenizerFast.from_pretrained("allenai/longformer-base-4096")
        tokens_existentes = set(tokenizer_tmp.get_vocab().keys())
        if logger:
            logger.info("📥 Tokenizador base cargado para comparación de vocabulario.")

    terminos_nuevos = [t for t in terminos_tecnicos if t not in tokens_existentes]
    if logger:
        logger.info(f"🆕 Términos nuevos detectados y añadidos: {len(terminos_nuevos)}")

    return terminos_nuevos

# %%
from datetime import datetime

def registrar_terminos_en_log(terminos_nuevos, lote_id, ruta_salida, logger=None):
    if not terminos_nuevos:
        if logger:
            logger.info("📋 No hay términos nuevos que registrar en el log.")
        return

    fecha = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    registros = [{"termino": t, "lote_id": lote_id, "fecha_hora": fecha} for t in terminos_nuevos]
    df_nuevos = pd.DataFrame(registros)

    ruta_log = os.path.join(ruta_salida, "registro_terminos_por_lote.csv")
    if os.path.exists(ruta_log):
        df_log = pd.read_csv(ruta_log)
        df_final = pd.concat([df_log, df_nuevos], ignore_index=True).drop_duplicates(subset=["termino"])
    else:
        df_final = df_nuevos

    df_final.to_csv(ruta_log, index=False, encoding="utf-8")
    if logger:
        logger.info(f"🗂 Registro actualizado: {len(terminos_nuevos)} términos añadidos al log.")

# %%
# ─── 4. Cargar modelo y tokenizador Longformer ───
from transformers import LongformerTokenizerFast, LongformerForSequenceClassification
import torch

logger.info("🔧 Cargando modelo y tokenizador Longformer…")
tokenizer = LongformerTokenizerFast.from_pretrained("allenai/longformer-base-4096")
model = LongformerForSequenceClassification.from_pretrained("allenai/longformer-base-4096", num_labels=3)

# Añadir nuevos tokens y redimensionar embeddings
modelo_dir_prev = os.path.join(entorno["ruta_entrada"], "modelo_ajustado")
terminos_nuevos = detectar_terminos_nuevos(terminos_tecnicos, modelo_dir_prev, logger=logger)
tokenizer.add_tokens(terminos_nuevos)
model.resize_token_embeddings(len(tokenizer))

# Congelar todo excepto embeddings
for param in model.parameters():
    param.requires_grad = False
model.longformer.embeddings.word_embeddings.weight.requires_grad = True
# Out:
# 2025-06-28 13:52:24,276 - INFO - 🔧 Cargando modelo y tokenizador Longformer…
# INFO:MODULO_04:🔧 Cargando modelo y tokenizador Longformer…
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/597M [00:00<?, ?B/s]
# Some weights of LongformerForSequenceClassification were not initialized from the model checkpoint at allenai/longformer-base-4096 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2025-06-28 13:52:34,425 - INFO - 📥 Tokenizador base cargado para comparación de vocabulario.
# INFO:MODULO_04:📥 Tokenizador base cargado para comparación de vocabulario.
# 2025-06-28 13:52:34,427 - INFO - 🆕 Términos nuevos detectados y añadidos: 13
# INFO:MODULO_04:🆕 Términos nuevos detectados y añadidos: 13
# model.safetensors:   0%|          | 0.00/597M [00:00<?, ?B/s]
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`

# %%
registrar_terminos_en_log(terminos_nuevos, lote_id, entorno["ruta_salida"], logger=logger)
# Out:
# 2025-06-28 13:54:53,997 - INFO - 🗂 Registro actualizado: 13 términos añadidos al log.
# INFO:MODULO_04:🗂 Registro actualizado: 13 términos añadidos al log.

# %%
# ---------------------------------------------
# 5. Entrenamiento de Embeddings
# ---------------------------------------------
from torch.utils.data import Dataset, DataLoader
# Si no hiciste división y no tienes train_labels, generamos etiquetas vacías o ficitcias
if "train_labels" not in locals() or len(train_labels) != len(train_texts):
    logger.warning("⚠️ No se encontraron etiquetas. Se asignarán etiquetas ficticias (0) a todo el dataset.")
    train_labels = [0] * len(train_texts)

# Tokenizar con truncado y padding explícito
inputs = tokenizer(
    train_texts,
    truncation=True,
    padding="max_length",
    max_length=512,
    return_tensors="pt"
)
# Añadir etiquetas
inputs["labels"] = torch.tensor(train_labels)

class SimpleDataset(Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        return {key: val[idx] for key, val in self.encodings.items()}

    def __len__(self):
        return len(self.encodings["input_ids"])

# Crear dataset y dataloader
dataset = SimpleDataset(inputs)
train_dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

# Optimizador solo para los embeddings entrenables
optimizer = torch.optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

logger.info("🚀 Iniciando ajuste de embeddings…")
model.train()
for epoch in range(2):
    for batch in train_dataloader:
        outputs = model(**batch)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        logger.info(f"Epoch {epoch} - Loss: {loss.item():.4f}")
# Out:
# 2025-06-28 13:54:56,526 - INFO - 🚀 Iniciando ajuste de embeddings…
# INFO:MODULO_04:🚀 Iniciando ajuste de embeddings…
# Initializing global attention on CLS token...
# 2025-06-28 13:54:58,420 - INFO - Epoch 0 - Loss: 0.9700
# INFO:MODULO_04:Epoch 0 - Loss: 0.9700
# 2025-06-28 13:54:59,915 - INFO - Epoch 0 - Loss: 1.2311
# INFO:MODULO_04:Epoch 0 - Loss: 1.2311
# 2025-06-28 13:55:01,322 - INFO - Epoch 0 - Loss: 1.0805
# INFO:MODULO_04:Epoch 0 - Loss: 1.0805
# 2025-06-28 13:55:02,879 - INFO - Epoch 0 - Loss: 1.1305
# INFO:MODULO_04:Epoch 0 - Loss: 1.1305
# 2025-06-28 13:55:04,824 - INFO - Epoch 0 - Loss: 1.0169
# INFO:MODULO_04:Epoch 0 - Loss: 1.0169
# 2025-06-28 13:55:06,262 - INFO - Epoch 0 - Loss: 1.0673
# INFO:MODULO_04:Epoch 0 - Loss: 1.0673
# 2025-06-28 13:55:07,698 - INFO - Epoch 0 - Loss: 1.1415
# INFO:MODULO_04:Epoch 0 - Loss: 1.1415
# 2025-06-28 13:55:09,138 - INFO - Epoch 0 - Loss: 1.0876
# INFO:MODULO_04:Epoch 0 - Loss: 1.0876
# 2025-06-28 13:55:10,492 - INFO - Epoch 0 - Loss: 1.2066
# INFO:MODULO_04:Epoch 0 - Loss: 1.2066
# 2025-06-28 13:55:11,900 - INFO - Epoch 0 - Loss: 1.0594
# INFO:MODULO_04:Epoch 0 - Loss: 1.0594
# 2025-06-28 13:55:13,321 - INFO - Epoch 0 - Loss: 1.0275
# INFO:MODULO_04:Epoch 0 - Loss: 1.0275
# 2025-06-28 13:55:14,810 - INFO - Epoch 0 - Loss: 1.0080
# INFO:MODULO_04:Epoch 0 - Loss: 1.0080
# 2025-06-28 13:55:16,498 - INFO - Epoch 0 - Loss: 0.9691
# INFO:MODULO_04:Epoch 0 - Loss: 0.9691
# 2025-06-28 13:55:18,209 - INFO - Epoch 0 - Loss: 1.0857
# INFO:MODULO_04:Epoch 0 - Loss: 1.0857
# 2025-06-28 13:55:19,644 - INFO - Epoch 0 - Loss: 1.0575
# INFO:MODULO_04:Epoch 0 - Loss: 1.0575
# 2025-06-28 13:55:21,020 - INFO - Epoch 0 - Loss: 1.0384
# INFO:MODULO_04:Epoch 0 - Loss: 1.0384
# 2025-06-28 13:55:22,443 - INFO - Epoch 0 - Loss: 0.9587
# INFO:MODULO_04:Epoch 0 - Loss: 0.9587
# 2025-06-28 13:55:23,874 - INFO - Epoch 0 - Loss: 1.0454
# INFO:MODULO_04:Epoch 0 - Loss: 1.0454
# 2025-06-28 13:55:25,328 - INFO - Epoch 0 - Loss: 1.0799
# INFO:MODULO_04:Epoch 0 - Loss: 1.0799
# 2025-06-28 13:55:26,738 - INFO - Epoch 0 - Loss: 1.0400
# INFO:MODULO_04:Epoch 0 - Loss: 1.0400
# 2025-06-28 13:55:28,285 - INFO - Epoch 0 - Loss: 0.9885
# INFO:MODULO_04:Epoch 0 - Loss: 0.9885
# 2025-06-28 13:55:30,207 - INFO - Epoch 0 - Loss: 1.0071
# INFO:MODULO_04:Epoch 0 - Loss: 1.0071
# 2025-06-28 13:55:31,641 - INFO - Epoch 0 - Loss: 0.9578
# INFO:MODULO_04:Epoch 0 - Loss: 0.9578
# 2025-06-28 13:55:32,969 - INFO - Epoch 0 - Loss: 1.1921
# INFO:MODULO_04:Epoch 0 - Loss: 1.1921
# 2025-06-28 13:55:34,373 - INFO - Epoch 0 - Loss: 1.0861
# INFO:MODULO_04:Epoch 0 - Loss: 1.0861
# 2025-06-28 13:55:35,810 - INFO - Epoch 0 - Loss: 1.1026
# INFO:MODULO_04:Epoch 0 - Loss: 1.1026
# 2025-06-28 13:55:37,243 - INFO - Epoch 0 - Loss: 1.1853
# INFO:MODULO_04:Epoch 0 - Loss: 1.1853
# 2025-06-28 13:55:38,658 - INFO - Epoch 0 - Loss: 1.0859
# INFO:MODULO_04:Epoch 0 - Loss: 1.0859
# 2025-06-28 13:55:40,171 - INFO - Epoch 0 - Loss: 1.0580
# INFO:MODULO_04:Epoch 0 - Loss: 1.0580
# 2025-06-28 13:55:41,838 - INFO - Epoch 0 - Loss: 1.2500
# INFO:MODULO_04:Epoch 0 - Loss: 1.2500
# 2025-06-28 13:55:43,536 - INFO - Epoch 0 - Loss: 1.1333
# INFO:MODULO_04:Epoch 0 - Loss: 1.1333
# 2025-06-28 13:55:44,995 - INFO - Epoch 0 - Loss: 1.0503
# INFO:MODULO_04:Epoch 0 - Loss: 1.0503
# 2025-06-28 13:55:46,426 - INFO - Epoch 0 - Loss: 1.0355
# INFO:MODULO_04:Epoch 0 - Loss: 1.0355
# 2025-06-28 13:55:47,856 - INFO - Epoch 0 - Loss: 1.0221
# INFO:MODULO_04:Epoch 0 - Loss: 1.0221
# 2025-06-28 13:55:49,285 - INFO - Epoch 0 - Loss: 1.0289
# INFO:MODULO_04:Epoch 0 - Loss: 1.0289
# 2025-06-28 13:55:50,700 - INFO - Epoch 0 - Loss: 1.0850
# INFO:MODULO_04:Epoch 0 - Loss: 1.0850
# 2025-06-28 13:55:52,118 - INFO - Epoch 0 - Loss: 1.1580
# INFO:MODULO_04:Epoch 0 - Loss: 1.1580
# 2025-06-28 13:55:53,565 - INFO - Epoch 0 - Loss: 1.0452
# INFO:MODULO_04:Epoch 0 - Loss: 1.0452
# 2025-06-28 13:55:55,552 - INFO - Epoch 0 - Loss: 1.1729
# INFO:MODULO_04:Epoch 0 - Loss: 1.1729
# 2025-06-28 13:55:56,999 - INFO - Epoch 0 - Loss: 1.0888
# INFO:MODULO_04:Epoch 0 - Loss: 1.0888
# 2025-06-28 13:55:58,431 - INFO - Epoch 0 - Loss: 1.1429
# INFO:MODULO_04:Epoch 0 - Loss: 1.1429
# 2025-06-28 13:55:59,852 - INFO - Epoch 0 - Loss: 0.9743
# INFO:MODULO_04:Epoch 0 - Loss: 0.9743
# 2025-06-28 13:56:01,299 - INFO - Epoch 0 - Loss: 1.0410
# INFO:MODULO_04:Epoch 0 - Loss: 1.0410
# 2025-06-28 13:56:02,723 - INFO - Epoch 0 - Loss: 1.0761
# INFO:MODULO_04:Epoch 0 - Loss: 1.0761
# 2025-06-28 13:56:04,169 - INFO - Epoch 0 - Loss: 1.0721
# INFO:MODULO_04:Epoch 0 - Loss: 1.0721
# 2025-06-28 13:56:05,680 - INFO - Epoch 0 - Loss: 1.0122
# INFO:MODULO_04:Epoch 0 - Loss: 1.0122
# 2025-06-28 13:56:07,299 - INFO - Epoch 0 - Loss: 1.2144
# INFO:MODULO_04:Epoch 0 - Loss: 1.2144
# 2025-06-28 13:56:08,944 - INFO - Epoch 0 - Loss: 1.0726
# INFO:MODULO_04:Epoch 0 - Loss: 1.0726
# 2025-06-28 13:56:10,355 - INFO - Epoch 0 - Loss: 1.0628
# INFO:MODULO_04:Epoch 0 - Loss: 1.0628
# 2025-06-28 13:56:11,778 - INFO - Epoch 0 - Loss: 1.0198
# INFO:MODULO_04:Epoch 0 - Loss: 1.0198
# 2025-06-28 13:56:13,107 - INFO - Epoch 0 - Loss: 1.0338
# INFO:MODULO_04:Epoch 0 - Loss: 1.0338
# 2025-06-28 13:56:14,530 - INFO - Epoch 0 - Loss: 0.9997
# INFO:MODULO_04:Epoch 0 - Loss: 0.9997
# 2025-06-28 13:56:15,877 - INFO - Epoch 0 - Loss: 1.0568
# INFO:MODULO_04:Epoch 0 - Loss: 1.0568
# 2025-06-28 13:56:17,256 - INFO - Epoch 0 - Loss: 1.0189
# INFO:MODULO_04:Epoch 0 - Loss: 1.0189
# 2025-06-28 13:56:18,702 - INFO - Epoch 0 - Loss: 0.8502
# INFO:MODULO_04:Epoch 0 - Loss: 0.8502
# 2025-06-28 13:56:20,302 - INFO - Epoch 0 - Loss: 1.0040
# INFO:MODULO_04:Epoch 0 - Loss: 1.0040
# 2025-06-28 13:56:22,085 - INFO - Epoch 0 - Loss: 1.1019
# INFO:MODULO_04:Epoch 0 - Loss: 1.1019
# 2025-06-28 13:56:23,510 - INFO - Epoch 0 - Loss: 1.2740
# INFO:MODULO_04:Epoch 0 - Loss: 1.2740
# 2025-06-28 13:56:24,894 - INFO - Epoch 0 - Loss: 1.0626
# INFO:MODULO_04:Epoch 0 - Loss: 1.0626
# 2025-06-28 13:56:26,362 - INFO - Epoch 0 - Loss: 1.0926
# INFO:MODULO_04:Epoch 0 - Loss: 1.0926
# 2025-06-28 13:56:27,761 - INFO - Epoch 0 - Loss: 1.0332
# INFO:MODULO_04:Epoch 0 - Loss: 1.0332
# 2025-06-28 13:56:29,173 - INFO - Epoch 0 - Loss: 1.1152
# INFO:MODULO_04:Epoch 0 - Loss: 1.1152
# 2025-06-28 13:56:30,631 - INFO - Epoch 0 - Loss: 1.0268
# INFO:MODULO_04:Epoch 0 - Loss: 1.0268
# 2025-06-28 13:56:32,143 - INFO - Epoch 0 - Loss: 1.0127
# INFO:MODULO_04:Epoch 0 - Loss: 1.0127
# 2025-06-28 13:56:34,124 - INFO - Epoch 0 - Loss: 1.1764
# INFO:MODULO_04:Epoch 0 - Loss: 1.1764
# 2025-06-28 13:56:35,571 - INFO - Epoch 0 - Loss: 1.0485
# INFO:MODULO_04:Epoch 0 - Loss: 1.0485
# 2025-06-28 13:56:36,976 - INFO - Epoch 0 - Loss: 1.1618
# INFO:MODULO_04:Epoch 0 - Loss: 1.1618
# 2025-06-28 13:56:38,411 - INFO - Epoch 0 - Loss: 1.2177
# INFO:MODULO_04:Epoch 0 - Loss: 1.2177
# 2025-06-28 13:56:39,828 - INFO - Epoch 0 - Loss: 1.0865
# INFO:MODULO_04:Epoch 0 - Loss: 1.0865
# 2025-06-28 13:56:41,274 - INFO - Epoch 0 - Loss: 1.0338
# INFO:MODULO_04:Epoch 0 - Loss: 1.0338
# 2025-06-28 13:56:42,716 - INFO - Epoch 0 - Loss: 1.0294
# INFO:MODULO_04:Epoch 0 - Loss: 1.0294
# 2025-06-28 13:56:44,167 - INFO - Epoch 0 - Loss: 1.1709
# INFO:MODULO_04:Epoch 0 - Loss: 1.1709
# 2025-06-28 13:56:46,182 - INFO - Epoch 0 - Loss: 1.0662
# INFO:MODULO_04:Epoch 0 - Loss: 1.0662
# 2025-06-28 13:56:47,662 - INFO - Epoch 0 - Loss: 1.0254
# INFO:MODULO_04:Epoch 0 - Loss: 1.0254
# 2025-06-28 13:56:49,048 - INFO - Epoch 0 - Loss: 0.9601
# INFO:MODULO_04:Epoch 0 - Loss: 0.9601
# 2025-06-28 13:56:50,492 - INFO - Epoch 0 - Loss: 1.2032
# INFO:MODULO_04:Epoch 0 - Loss: 1.2032
# 2025-06-28 13:56:51,926 - INFO - Epoch 0 - Loss: 1.2741
# INFO:MODULO_04:Epoch 0 - Loss: 1.2741
# 2025-06-28 13:56:53,315 - INFO - Epoch 0 - Loss: 1.0506
# INFO:MODULO_04:Epoch 0 - Loss: 1.0506
# 2025-06-28 13:56:54,782 - INFO - Epoch 0 - Loss: 1.0620
# INFO:MODULO_04:Epoch 0 - Loss: 1.0620
# 2025-06-28 13:56:56,216 - INFO - Epoch 0 - Loss: 0.9897
# INFO:MODULO_04:Epoch 0 - Loss: 0.9897
# 2025-06-28 13:56:58,252 - INFO - Epoch 0 - Loss: 1.0836
# INFO:MODULO_04:Epoch 0 - Loss: 1.0836
# 2025-06-28 13:56:59,783 - INFO - Epoch 0 - Loss: 1.0380
# INFO:MODULO_04:Epoch 0 - Loss: 1.0380
# 2025-06-28 13:57:01,252 - INFO - Epoch 0 - Loss: 1.0294
# INFO:MODULO_04:Epoch 0 - Loss: 1.0294
# 2025-06-28 13:57:02,668 - INFO - Epoch 0 - Loss: 1.0465
# INFO:MODULO_04:Epoch 0 - Loss: 1.0465
# 2025-06-28 13:57:04,155 - INFO - Epoch 0 - Loss: 0.9261
# INFO:MODULO_04:Epoch 0 - Loss: 0.9261
# 2025-06-28 13:57:05,593 - INFO - Epoch 0 - Loss: 1.1557
# INFO:MODULO_04:Epoch 0 - Loss: 1.1557
# 2025-06-28 13:57:07,018 - INFO - Epoch 0 - Loss: 1.1629
# INFO:MODULO_04:Epoch 0 - Loss: 1.1629
# 2025-06-28 13:57:08,467 - INFO - Epoch 0 - Loss: 0.9950
# INFO:MODULO_04:Epoch 0 - Loss: 0.9950
# 2025-06-28 13:57:10,095 - INFO - Epoch 0 - Loss: 1.0157
# INFO:MODULO_04:Epoch 0 - Loss: 1.0157
# 2025-06-28 13:57:11,923 - INFO - Epoch 0 - Loss: 1.0802
# INFO:MODULO_04:Epoch 0 - Loss: 1.0802
# 2025-06-28 13:57:13,413 - INFO - Epoch 0 - Loss: 1.0518
# INFO:MODULO_04:Epoch 0 - Loss: 1.0518
# 2025-06-28 13:57:14,852 - INFO - Epoch 0 - Loss: 1.0896
# INFO:MODULO_04:Epoch 0 - Loss: 1.0896
# 2025-06-28 13:57:16,274 - INFO - Epoch 0 - Loss: 1.1437
# INFO:MODULO_04:Epoch 0 - Loss: 1.1437
# 2025-06-28 13:57:17,687 - INFO - Epoch 0 - Loss: 1.0201
# INFO:MODULO_04:Epoch 0 - Loss: 1.0201
# 2025-06-28 13:57:19,118 - INFO - Epoch 0 - Loss: 1.2783
# INFO:MODULO_04:Epoch 0 - Loss: 1.2783
# 2025-06-28 13:57:20,568 - INFO - Epoch 0 - Loss: 1.1587
# INFO:MODULO_04:Epoch 0 - Loss: 1.1587
# 2025-06-28 13:57:22,071 - INFO - Epoch 0 - Loss: 1.0089
# INFO:MODULO_04:Epoch 0 - Loss: 1.0089
# 2025-06-28 13:57:23,683 - INFO - Epoch 0 - Loss: 1.0521
# INFO:MODULO_04:Epoch 0 - Loss: 1.0521
# 2025-06-28 13:57:25,333 - INFO - Epoch 0 - Loss: 1.0310
# INFO:MODULO_04:Epoch 0 - Loss: 1.0310
# 2025-06-28 13:57:26,758 - INFO - Epoch 0 - Loss: 1.1180
# INFO:MODULO_04:Epoch 0 - Loss: 1.1180
# 2025-06-28 13:57:28,177 - INFO - Epoch 0 - Loss: 1.0450
# INFO:MODULO_04:Epoch 0 - Loss: 1.0450
# 2025-06-28 13:57:29,600 - INFO - Epoch 0 - Loss: 1.0664
# INFO:MODULO_04:Epoch 0 - Loss: 1.0664
# 2025-06-28 13:57:31,014 - INFO - Epoch 0 - Loss: 1.0389
# INFO:MODULO_04:Epoch 0 - Loss: 1.0389
# 2025-06-28 13:57:32,430 - INFO - Epoch 0 - Loss: 1.1986
# INFO:MODULO_04:Epoch 0 - Loss: 1.1986
# 2025-06-28 13:57:33,868 - INFO - Epoch 0 - Loss: 0.9555
# INFO:MODULO_04:Epoch 0 - Loss: 0.9555
# 2025-06-28 13:57:35,479 - INFO - Epoch 0 - Loss: 0.9857
# INFO:MODULO_04:Epoch 0 - Loss: 0.9857
# 2025-06-28 13:57:37,114 - INFO - Epoch 0 - Loss: 1.0093
# INFO:MODULO_04:Epoch 0 - Loss: 1.0093
# 2025-06-28 13:57:38,631 - INFO - Epoch 0 - Loss: 1.0647
# INFO:MODULO_04:Epoch 0 - Loss: 1.0647
# 2025-06-28 13:57:40,064 - INFO - Epoch 0 - Loss: 1.0644
# INFO:MODULO_04:Epoch 0 - Loss: 1.0644
# 2025-06-28 13:57:41,467 - INFO - Epoch 0 - Loss: 1.0330
# INFO:MODULO_04:Epoch 0 - Loss: 1.0330
# 2025-06-28 13:57:42,910 - INFO - Epoch 0 - Loss: 1.1169
# INFO:MODULO_04:Epoch 0 - Loss: 1.1169
# 2025-06-28 13:57:44,348 - INFO - Epoch 0 - Loss: 1.0016
# INFO:MODULO_04:Epoch 0 - Loss: 1.0016
# 2025-06-28 13:57:45,764 - INFO - Epoch 1 - Loss: 0.9159
# INFO:MODULO_04:Epoch 1 - Loss: 0.9159
# 2025-06-28 13:57:47,148 - INFO - Epoch 1 - Loss: 1.0288
# INFO:MODULO_04:Epoch 1 - Loss: 1.0288
# 2025-06-28 13:57:48,739 - INFO - Epoch 1 - Loss: 1.0382
# INFO:MODULO_04:Epoch 1 - Loss: 1.0382
# 2025-06-28 13:57:50,497 - INFO - Epoch 1 - Loss: 1.0965
# INFO:MODULO_04:Epoch 1 - Loss: 1.0965
# 2025-06-28 13:57:51,962 - INFO - Epoch 1 - Loss: 1.0886
# INFO:MODULO_04:Epoch 1 - Loss: 1.0886
# 2025-06-28 13:57:53,355 - INFO - Epoch 1 - Loss: 1.1193
# INFO:MODULO_04:Epoch 1 - Loss: 1.1193
# 2025-06-28 13:57:54,796 - INFO - Epoch 1 - Loss: 1.1530
# INFO:MODULO_04:Epoch 1 - Loss: 1.1530
# 2025-06-28 13:57:56,196 - INFO - Epoch 1 - Loss: 1.0791
# INFO:MODULO_04:Epoch 1 - Loss: 1.0791
# 2025-06-28 13:57:57,626 - INFO - Epoch 1 - Loss: 1.0360
# INFO:MODULO_04:Epoch 1 - Loss: 1.0360
# 2025-06-28 13:57:58,957 - INFO - Epoch 1 - Loss: 1.2500
# INFO:MODULO_04:Epoch 1 - Loss: 1.2500
# 2025-06-28 13:58:00,371 - INFO - Epoch 1 - Loss: 0.9683
# INFO:MODULO_04:Epoch 1 - Loss: 0.9683
# 2025-06-28 13:58:01,984 - INFO - Epoch 1 - Loss: 1.1314
# INFO:MODULO_04:Epoch 1 - Loss: 1.1314
# 2025-06-28 13:58:03,792 - INFO - Epoch 1 - Loss: 1.0217
# INFO:MODULO_04:Epoch 1 - Loss: 1.0217
# 2025-06-28 13:58:05,217 - INFO - Epoch 1 - Loss: 1.1247
# INFO:MODULO_04:Epoch 1 - Loss: 1.1247
# 2025-06-28 13:58:06,643 - INFO - Epoch 1 - Loss: 1.0058
# INFO:MODULO_04:Epoch 1 - Loss: 1.0058
# 2025-06-28 13:58:08,053 - INFO - Epoch 1 - Loss: 1.0459
# INFO:MODULO_04:Epoch 1 - Loss: 1.0459
# 2025-06-28 13:58:09,453 - INFO - Epoch 1 - Loss: 1.0321
# INFO:MODULO_04:Epoch 1 - Loss: 1.0321
# 2025-06-28 13:58:10,874 - INFO - Epoch 1 - Loss: 1.0557
# INFO:MODULO_04:Epoch 1 - Loss: 1.0557
# 2025-06-28 13:58:12,309 - INFO - Epoch 1 - Loss: 1.1587
# INFO:MODULO_04:Epoch 1 - Loss: 1.1587
# 2025-06-28 13:58:13,797 - INFO - Epoch 1 - Loss: 1.0298
# INFO:MODULO_04:Epoch 1 - Loss: 1.0298
# 2025-06-28 13:58:15,379 - INFO - Epoch 1 - Loss: 1.0683
# INFO:MODULO_04:Epoch 1 - Loss: 1.0683
# 2025-06-28 13:58:17,041 - INFO - Epoch 1 - Loss: 1.2046
# INFO:MODULO_04:Epoch 1 - Loss: 1.2046
# 2025-06-28 13:58:18,499 - INFO - Epoch 1 - Loss: 1.1177
# INFO:MODULO_04:Epoch 1 - Loss: 1.1177
# 2025-06-28 13:58:19,901 - INFO - Epoch 1 - Loss: 1.2687
# INFO:MODULO_04:Epoch 1 - Loss: 1.2687
# 2025-06-28 13:58:21,325 - INFO - Epoch 1 - Loss: 1.0727
# INFO:MODULO_04:Epoch 1 - Loss: 1.0727
# 2025-06-28 13:58:22,753 - INFO - Epoch 1 - Loss: 1.0685
# INFO:MODULO_04:Epoch 1 - Loss: 1.0685
# 2025-06-28 13:58:24,175 - INFO - Epoch 1 - Loss: 0.9890
# INFO:MODULO_04:Epoch 1 - Loss: 0.9890
# 2025-06-28 13:58:25,613 - INFO - Epoch 1 - Loss: 1.1416
# INFO:MODULO_04:Epoch 1 - Loss: 1.1416
# 2025-06-28 13:58:27,057 - INFO - Epoch 1 - Loss: 1.1008
# INFO:MODULO_04:Epoch 1 - Loss: 1.1008
# 2025-06-28 13:58:28,690 - INFO - Epoch 1 - Loss: 1.0183
# INFO:MODULO_04:Epoch 1 - Loss: 1.0183
# 2025-06-28 13:58:30,452 - INFO - Epoch 1 - Loss: 1.0365
# INFO:MODULO_04:Epoch 1 - Loss: 1.0365
# 2025-06-28 13:58:31,876 - INFO - Epoch 1 - Loss: 1.0019
# INFO:MODULO_04:Epoch 1 - Loss: 1.0019
# 2025-06-28 13:58:33,286 - INFO - Epoch 1 - Loss: 1.0358
# INFO:MODULO_04:Epoch 1 - Loss: 1.0358
# 2025-06-28 13:58:34,700 - INFO - Epoch 1 - Loss: 1.2020
# INFO:MODULO_04:Epoch 1 - Loss: 1.2020
# 2025-06-28 13:58:36,108 - INFO - Epoch 1 - Loss: 1.0604
# INFO:MODULO_04:Epoch 1 - Loss: 1.0604
# 2025-06-28 13:58:37,529 - INFO - Epoch 1 - Loss: 1.0257
# INFO:MODULO_04:Epoch 1 - Loss: 1.0257
# 2025-06-28 13:58:38,950 - INFO - Epoch 1 - Loss: 1.0160
# INFO:MODULO_04:Epoch 1 - Loss: 1.0160
# 2025-06-28 13:58:40,528 - INFO - Epoch 1 - Loss: 1.0900
# INFO:MODULO_04:Epoch 1 - Loss: 1.0900
# 2025-06-28 13:58:42,466 - INFO - Epoch 1 - Loss: 1.0089
# INFO:MODULO_04:Epoch 1 - Loss: 1.0089
# 2025-06-28 13:58:43,863 - INFO - Epoch 1 - Loss: 1.0570
# INFO:MODULO_04:Epoch 1 - Loss: 1.0570
# 2025-06-28 13:58:45,282 - INFO - Epoch 1 - Loss: 1.0100
# INFO:MODULO_04:Epoch 1 - Loss: 1.0100
# 2025-06-28 13:58:46,643 - INFO - Epoch 1 - Loss: 0.8975
# INFO:MODULO_04:Epoch 1 - Loss: 0.8975
# 2025-06-28 13:58:48,073 - INFO - Epoch 1 - Loss: 1.0616
# INFO:MODULO_04:Epoch 1 - Loss: 1.0616
# 2025-06-28 13:58:49,502 - INFO - Epoch 1 - Loss: 1.0675
# INFO:MODULO_04:Epoch 1 - Loss: 1.0675
# 2025-06-28 13:58:50,938 - INFO - Epoch 1 - Loss: 0.9038
# INFO:MODULO_04:Epoch 1 - Loss: 0.9038
# 2025-06-28 13:58:52,343 - INFO - Epoch 1 - Loss: 1.0254
# INFO:MODULO_04:Epoch 1 - Loss: 1.0254
# 2025-06-28 13:58:54,456 - INFO - Epoch 1 - Loss: 0.9665
# INFO:MODULO_04:Epoch 1 - Loss: 0.9665
# 2025-06-28 13:58:55,898 - INFO - Epoch 1 - Loss: 1.1906
# INFO:MODULO_04:Epoch 1 - Loss: 1.1906
# 2025-06-28 13:58:57,322 - INFO - Epoch 1 - Loss: 1.0453
# INFO:MODULO_04:Epoch 1 - Loss: 1.0453
# 2025-06-28 13:58:58,738 - INFO - Epoch 1 - Loss: 1.2128
# INFO:MODULO_04:Epoch 1 - Loss: 1.2128
# 2025-06-28 13:59:00,170 - INFO - Epoch 1 - Loss: 1.0027
# INFO:MODULO_04:Epoch 1 - Loss: 1.0027
# 2025-06-28 13:59:01,588 - INFO - Epoch 1 - Loss: 1.1130
# INFO:MODULO_04:Epoch 1 - Loss: 1.1130
# 2025-06-28 13:59:03,012 - INFO - Epoch 1 - Loss: 1.0668
# INFO:MODULO_04:Epoch 1 - Loss: 1.0668
# 2025-06-28 13:59:04,384 - INFO - Epoch 1 - Loss: 1.2060
# INFO:MODULO_04:Epoch 1 - Loss: 1.2060
# 2025-06-28 13:59:06,360 - INFO - Epoch 1 - Loss: 1.0770
# INFO:MODULO_04:Epoch 1 - Loss: 1.0770
# 2025-06-28 13:59:07,877 - INFO - Epoch 1 - Loss: 1.1691
# INFO:MODULO_04:Epoch 1 - Loss: 1.1691
# 2025-06-28 13:59:09,285 - INFO - Epoch 1 - Loss: 1.0381
# INFO:MODULO_04:Epoch 1 - Loss: 1.0381
# 2025-06-28 13:59:10,684 - INFO - Epoch 1 - Loss: 0.9655
# INFO:MODULO_04:Epoch 1 - Loss: 0.9655
# 2025-06-28 13:59:12,092 - INFO - Epoch 1 - Loss: 0.9947
# INFO:MODULO_04:Epoch 1 - Loss: 0.9947
# 2025-06-28 13:59:13,513 - INFO - Epoch 1 - Loss: 1.0213
# INFO:MODULO_04:Epoch 1 - Loss: 1.0213
# 2025-06-28 13:59:14,945 - INFO - Epoch 1 - Loss: 1.1927
# INFO:MODULO_04:Epoch 1 - Loss: 1.1927
# 2025-06-28 13:59:16,359 - INFO - Epoch 1 - Loss: 0.8361
# INFO:MODULO_04:Epoch 1 - Loss: 0.8361
# 2025-06-28 13:59:17,993 - INFO - Epoch 1 - Loss: 1.0056
# INFO:MODULO_04:Epoch 1 - Loss: 1.0056
# 2025-06-28 13:59:19,825 - INFO - Epoch 1 - Loss: 0.9845
# INFO:MODULO_04:Epoch 1 - Loss: 0.9845
# 2025-06-28 13:59:21,262 - INFO - Epoch 1 - Loss: 1.0462
# INFO:MODULO_04:Epoch 1 - Loss: 1.0462
# 2025-06-28 13:59:22,683 - INFO - Epoch 1 - Loss: 1.1504
# INFO:MODULO_04:Epoch 1 - Loss: 1.1504
# 2025-06-28 13:59:24,129 - INFO - Epoch 1 - Loss: 1.0475
# INFO:MODULO_04:Epoch 1 - Loss: 1.0475
# 2025-06-28 13:59:25,544 - INFO - Epoch 1 - Loss: 0.9737
# INFO:MODULO_04:Epoch 1 - Loss: 0.9737
# 2025-06-28 13:59:26,990 - INFO - Epoch 1 - Loss: 1.1328
# INFO:MODULO_04:Epoch 1 - Loss: 1.1328
# 2025-06-28 13:59:28,433 - INFO - Epoch 1 - Loss: 0.9808
# INFO:MODULO_04:Epoch 1 - Loss: 0.9808
# 2025-06-28 13:59:29,965 - INFO - Epoch 1 - Loss: 0.9937
# INFO:MODULO_04:Epoch 1 - Loss: 0.9937
# 2025-06-28 13:59:31,958 - INFO - Epoch 1 - Loss: 0.9994
# INFO:MODULO_04:Epoch 1 - Loss: 0.9994
# 2025-06-28 13:59:33,382 - INFO - Epoch 1 - Loss: 1.1567
# INFO:MODULO_04:Epoch 1 - Loss: 1.1567
# 2025-06-28 13:59:34,809 - INFO - Epoch 1 - Loss: 1.0311
# INFO:MODULO_04:Epoch 1 - Loss: 1.0311
# 2025-06-28 13:59:36,203 - INFO - Epoch 1 - Loss: 1.0730
# INFO:MODULO_04:Epoch 1 - Loss: 1.0730
# 2025-06-28 13:59:37,624 - INFO - Epoch 1 - Loss: 1.0318
# INFO:MODULO_04:Epoch 1 - Loss: 1.0318
# 2025-06-28 13:59:39,019 - INFO - Epoch 1 - Loss: 0.9821
# INFO:MODULO_04:Epoch 1 - Loss: 0.9821
# 2025-06-28 13:59:40,439 - INFO - Epoch 1 - Loss: 0.9797
# INFO:MODULO_04:Epoch 1 - Loss: 0.9797
# 2025-06-28 13:59:41,882 - INFO - Epoch 1 - Loss: 1.0206
# INFO:MODULO_04:Epoch 1 - Loss: 1.0206
# 2025-06-28 13:59:43,415 - INFO - Epoch 1 - Loss: 1.0769
# INFO:MODULO_04:Epoch 1 - Loss: 1.0769
# 2025-06-28 13:59:45,089 - INFO - Epoch 1 - Loss: 1.0496
# INFO:MODULO_04:Epoch 1 - Loss: 1.0496
# 2025-06-28 13:59:46,520 - INFO - Epoch 1 - Loss: 1.0453
# INFO:MODULO_04:Epoch 1 - Loss: 1.0453
# 2025-06-28 13:59:47,934 - INFO - Epoch 1 - Loss: 1.0310
# INFO:MODULO_04:Epoch 1 - Loss: 1.0310
# 2025-06-28 13:59:49,368 - INFO - Epoch 1 - Loss: 0.9827
# INFO:MODULO_04:Epoch 1 - Loss: 0.9827
# 2025-06-28 13:59:50,795 - INFO - Epoch 1 - Loss: 1.0253
# INFO:MODULO_04:Epoch 1 - Loss: 1.0253
# 2025-06-28 13:59:52,238 - INFO - Epoch 1 - Loss: 1.2284
# INFO:MODULO_04:Epoch 1 - Loss: 1.2284
# 2025-06-28 13:59:53,667 - INFO - Epoch 1 - Loss: 1.1727
# INFO:MODULO_04:Epoch 1 - Loss: 1.1727
# 2025-06-28 13:59:55,077 - INFO - Epoch 1 - Loss: 1.0119
# INFO:MODULO_04:Epoch 1 - Loss: 1.0119
# 2025-06-28 13:59:56,679 - INFO - Epoch 1 - Loss: 0.9916
# INFO:MODULO_04:Epoch 1 - Loss: 0.9916
# 2025-06-28 13:59:58,319 - INFO - Epoch 1 - Loss: 1.2967
# INFO:MODULO_04:Epoch 1 - Loss: 1.2967
# 2025-06-28 13:59:59,768 - INFO - Epoch 1 - Loss: 1.1879
# INFO:MODULO_04:Epoch 1 - Loss: 1.1879
# 2025-06-28 14:00:01,205 - INFO - Epoch 1 - Loss: 1.0597
# INFO:MODULO_04:Epoch 1 - Loss: 1.0597
# 2025-06-28 14:00:02,643 - INFO - Epoch 1 - Loss: 0.9183
# INFO:MODULO_04:Epoch 1 - Loss: 0.9183
# 2025-06-28 14:00:04,075 - INFO - Epoch 1 - Loss: 1.0017
# INFO:MODULO_04:Epoch 1 - Loss: 1.0017
# 2025-06-28 14:00:05,374 - INFO - Epoch 1 - Loss: 0.9914
# INFO:MODULO_04:Epoch 1 - Loss: 0.9914
# 2025-06-28 14:00:06,800 - INFO - Epoch 1 - Loss: 1.0235
# INFO:MODULO_04:Epoch 1 - Loss: 1.0235
# 2025-06-28 14:00:08,237 - INFO - Epoch 1 - Loss: 1.0403
# INFO:MODULO_04:Epoch 1 - Loss: 1.0403
# 2025-06-28 14:00:09,866 - INFO - Epoch 1 - Loss: 1.1535
# INFO:MODULO_04:Epoch 1 - Loss: 1.1535
# 2025-06-28 14:00:11,673 - INFO - Epoch 1 - Loss: 1.0878
# INFO:MODULO_04:Epoch 1 - Loss: 1.0878
# 2025-06-28 14:00:13,090 - INFO - Epoch 1 - Loss: 1.1309
# INFO:MODULO_04:Epoch 1 - Loss: 1.1309
# 2025-06-28 14:00:14,513 - INFO - Epoch 1 - Loss: 1.0494
# INFO:MODULO_04:Epoch 1 - Loss: 1.0494
# 2025-06-28 14:00:15,967 - INFO - Epoch 1 - Loss: 1.1323
# INFO:MODULO_04:Epoch 1 - Loss: 1.1323
# 2025-06-28 14:00:17,388 - INFO - Epoch 1 - Loss: 0.9295
# INFO:MODULO_04:Epoch 1 - Loss: 0.9295
# 2025-06-28 14:00:18,814 - INFO - Epoch 1 - Loss: 1.0515
# INFO:MODULO_04:Epoch 1 - Loss: 1.0515
# 2025-06-28 14:00:20,236 - INFO - Epoch 1 - Loss: 1.0795
# INFO:MODULO_04:Epoch 1 - Loss: 1.0795
# 2025-06-28 14:00:21,754 - INFO - Epoch 1 - Loss: 1.0183
# INFO:MODULO_04:Epoch 1 - Loss: 1.0183
# 2025-06-28 14:00:23,729 - INFO - Epoch 1 - Loss: 1.0517
# INFO:MODULO_04:Epoch 1 - Loss: 1.0517
# 2025-06-28 14:00:25,176 - INFO - Epoch 1 - Loss: 1.0116
# INFO:MODULO_04:Epoch 1 - Loss: 1.0116
# 2025-06-28 14:00:26,572 - INFO - Epoch 1 - Loss: 1.0876
# INFO:MODULO_04:Epoch 1 - Loss: 1.0876
# 2025-06-28 14:00:27,990 - INFO - Epoch 1 - Loss: 1.1677
# INFO:MODULO_04:Epoch 1 - Loss: 1.1677
# 2025-06-28 14:00:29,421 - INFO - Epoch 1 - Loss: 1.0584
# INFO:MODULO_04:Epoch 1 - Loss: 1.0584
# 2025-06-28 14:00:30,842 - INFO - Epoch 1 - Loss: 1.1273
# INFO:MODULO_04:Epoch 1 - Loss: 1.1273

# %%
# ---------------------------------------------
# 6. Guardar modelo ajustado
# ---------------------------------------------
modelo_dir = os.path.join(entorno["ruta_salida"], "modelo_ajustado")
os.makedirs(modelo_dir, exist_ok=True)
model.save_pretrained(modelo_dir)
tokenizer.save_pretrained(modelo_dir)
logger.info(f"💾 Modelo y tokenizador ajustados guardados en: {modelo_dir}")

logger.info(f"✅ Finalización del procesamiento del módulo {nombre_modulo}")
# Out:
# 2025-06-28 14:00:37,345 - INFO - 💾 Modelo y tokenizador ajustados guardados en: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_04/./salida/modelo_ajustado
# INFO:MODULO_04:💾 Modelo y tokenizador ajustados guardados en: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_04/./salida/modelo_ajustado
# 2025-06-28 14:00:37,346 - INFO - ✅ Finalización del procesamiento del módulo MODULO_04
# INFO:MODULO_04:✅ Finalización del procesamiento del módulo MODULO_04

# %%
print("🧾 Tokens añadidos al vocabulario:")
print(terminos_tecnicos[:10])  # primeros 10

print(f"\n🔢 Tamaño total del vocabulario tras expansión: {len(tokenizer)}")

# Mostrar ejemplo de cómo el modelo tokeniza una frase con términos nuevos
frase = "Sí señora, el hospital está cerca, será solo un momentito si viene andando"
tokens = tokenizer.tokenize(frase)
ids = tokenizer.convert_tokens_to_ids(tokens)

print("\n🧬 Tokenización de ejemplo:")
for tok, idx in zip(tokens, ids):
    print(f"{tok:<20} → id {idx}")
# Out:
# 🧾 Tokens añadidos al vocabulario:
# ['doña', 'cliente', 'datos', 'fallecimiento', 'gracias', 'hospital', 'momentito', 'propiedad', 'resto', 'doña cliente']
#
# 🔢 Tamaño total del vocabulario tras expansión: 50278
#
# 🧬 Tokenización de ejemplo:
# S                    → id 104
# ÃŃ                   → id 1977
# Ġse                  → id 842
# Ã±                   → id 6303
# ora                  → id 4330
# ,                    → id 6
# Ġel                  → id 1615
# Ġhospital            → id 1098
# Ġest                 → id 3304
# Ã¡                   → id 1526
# Ġc                   → id 740
# erc                  → id 11180
# a                    → id 102
# ,                    → id 6
# Ġser                 → id 6821
# Ã¡                   → id 1526
# Ġsolo                → id 5540
# Ġun                  → id 542
# Ġ                    → id 1437
# momentito            → id 50270
# Ġsi                  → id 3391
# Ġvi                  → id 12987
# ene                  → id 2552
# Ġand                 → id 8
# ando                 → id 5502

# %%
# ------------------------------------
# PASO 5: Guardar dataset salida con nombre estándar
# guardamos el dataset que ya generamos en el paso anterior
# lo arrastramos al siguiente módulo
# ------------------------------------
nombre_salida = os.path.join(
    entorno["ruta_salida"],
    f"dataset_{nombre_modulo.lower()}_{entorno['lote_id']}.csv"
)

utilidades_comunes.guardar_dataset(df_entrada, nombre_salida, logger=logger)
# Out:
# 2025-06-28 14:00:46,905 - INFO - 📦 Dataset guardado en: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_04/./salida/dataset_modulo_04_20250614.csv (140 filas, 4 columnas)
# INFO:MODULO_04:📦 Dataset guardado en: /content/drive/MyDrive/TFM_EVA_MARTIN/Modulos/MODULO_04/./salida/dataset_modulo_04_20250614.csv (140 filas, 4 columnas)

# %%
# ——— Sanity checks finales tras guardar el modelo ———
from transformers import AutoConfig, LongformerTokenizerFast, LongformerForSequenceClassification

#modelo_dir = "…/ruta_salida/modelo_ajustado"

# 1) Comprueba que el num_labels se guardó bien
cfg = AutoConfig.from_pretrained(modelo_dir)
print("✅ num_labels:", cfg.num_labels)  # debe mostrar 3

# 2) Comprueba el tamaño de vocabulario tras resize
tokenizer = LongformerTokenizerFast.from_pretrained(modelo_dir)
print("✅ vocab_size:", len(tokenizer))  # debe reflejar los tokens añadidos

# 3) Comprueba la forma de la capa de clasificación
model = LongformerForSequenceClassification.from_pretrained(modelo_dir, config=cfg)
print("✅ shape out_proj:", model.classifier.out_proj.weight.shape)  # e.g. (3, hidden_size)
# Out:
# ✅ num_labels: 3
# ✅ vocab_size: 50278
# ✅ shape out_proj: torch.Size([3, 768])
